# %%
import pandas as pd

# %%
#import file dataset (Airbnb_NewYork_2019.csv) from google drive
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1sHBKWxFdfXnkqOLu3jukduMRxg7Bz0-9' -O Airbnb_NewYork_2019.csv
# Out:
# --2024-12-09 07:02:18--  https://docs.google.com/uc?export=download&id=1sHBKWxFdfXnkqOLu3jukduMRxg7Bz0-9
# Resolving docs.google.com (docs.google.com)... 142.250.125.139, 142.250.125.138, 142.250.125.100, ...
# Connecting to docs.google.com (docs.google.com)|142.250.125.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1sHBKWxFdfXnkqOLu3jukduMRxg7Bz0-9&export=download [following]
# --2024-12-09 07:02:18--  https://drive.usercontent.google.com/download?id=1sHBKWxFdfXnkqOLu3jukduMRxg7Bz0-9&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.152.132, 2607:f8b0:4001:c56::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.152.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 431301 (421K) [application/octet-stream]
# Saving to: ‘Airbnb_NewYork_2019.csv’
#
# Airbnb_NewYork_2019 100%[===================>] 421.19K  --.-KB/s    in 0.004s
#
# 2024-12-09 07:02:20 (113 MB/s) - ‘Airbnb_NewYork_2019.csv’ saved [431301/431301]

# %%
df = pd.read_csv("Airbnb_NewYork_2019.csv")

# %% [markdown]
# #Exploratory Data Analysis

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  149.0             1.0                  9  2018-10-19
# 1  Entire home/apt  225.0             1.0                 45  2019-05-21
# 2     Private room  150.0             3.0                  0         NaN
# 3  Entire home/apt   89.0             1.0                270  2019-07-05
# 4  Entire home/apt   80.0            10.0                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2996 entries, 0 to 2995
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2996 non-null   int64
#  1   name                            2995 non-null   object
#  2   host_id                         2996 non-null   int64
#  3   host_name                       2994 non-null   object
#  4   neighbourhood_group             2996 non-null   object
#  5   neighbourhood                   2996 non-null   object
#  6   latitude                        2991 non-null   float64
#  7   longitude                       2989 non-null   float64
#  8   room_type                       2996 non-null   object
#  9   price                           2993 non-null   float64
#  10  minimum_nights                  2988 non-null   float64
#  11  number_of_reviews               2996 non-null   int64
#  12  last_review                     2851 non-null   object
#  13  reviews_per_month               2851 non-null   float64
#  14  calculated_host_listings_count  2996 non-null   int64
#  15  availability_365                2996 non-null   int64
# dtypes: float64(5), int64(5), object(6)
# memory usage: 374.6+ KB

# %% [markdown]
# #1. Check Missing Data

# %%
df.isnull()
# Out:
#          id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0     False  False    False      False                False          False
# 1     False  False    False      False                False          False
# 2     False  False    False      False                False          False
# 3     False  False    False      False                False          False
# 4     False  False    False      False                False          False
# ...     ...    ...      ...        ...                  ...            ...
# 2991  False  False    False      False                False          False
# 2992  False  False    False      False                False          False
# 2993  False  False    False      False                False          False
# 2994  False  False    False      False                False          False
# 2995  False  False    False      False                False          False
#
#       latitude  longitude  room_type  price  minimum_nights  \
# 0        False      False      False  False           False
# 1        False      False      False  False           False
# 2        False      False      False  False           False
# 3        False      False      False  False           False
# 4        False      False      False  False           False
# ...        ...        ...        ...    ...             ...
# 2991     False      False      False  False           False
# 2992     False      False      False  False           False
# 2993     False      False      False  False           False
# 2994     False      False      False  False           False
# 2995     False      False      False  False           False
#
#       number_of_reviews  last_review  reviews_per_month  \
# 0                 False        False              False
# 1                 False        False              False
# 2                 False         True               True
# 3                 False        False              False
# 4                 False        False              False
# ...                 ...          ...                ...
# 2991              False        False              False
# 2992              False        False              False
# 2993              False        False              False
# 2994              False        False              False
# 2995              False        False              False
#
#       calculated_host_listings_count  availability_365
# 0                              False             False
# 1                              False             False
# 2                              False             False
# 3                              False             False
# 4                              False             False
# ...                              ...               ...
# 2991                           False             False
# 2992                           False             False
# 2993                           False             False
# 2994                           False             False
# 2995                           False             False
#
# [2996 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# id                                  0
# name                                1
# host_id                             0
# host_name                           2
# neighbourhood_group                 0
# neighbourhood                       0
# latitude                            5
# longitude                           7
# room_type                           0
# price                               3
# minimum_nights                      8
# number_of_reviews                   0
# last_review                       145
# reviews_per_month                 145
# calculated_host_listings_count      0
# availability_365                    0
# dtype: int64

# %% [markdown]
# #1.1 Input missing value

# %%
# imputing price with mean
price_mean_value = round(df['price'].mean(), 2)
df['price'].fillna(price_mean_value, inplace=True)
# Out:
# <ipython-input-177-29ef30268cb9>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(price_mean_value, inplace=True)

# %%
# TODO: imputing reviews_per_month with mean
reviews_per_month_values = round(df['reviews_per_month'].mean(), 2)
df['reviews_per_month'].fillna(reviews_per_month_values, inplace=True)
# reviews_per_month
# Out:
# <ipython-input-178-3dbbdbce633b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reviews_per_month'].fillna(reviews_per_month_values, inplace=True)

# %%
# TODO: replace null values in minimum_nights with 0
df["minimum_nights"].fillna(0, inplace=True)
# Out:
# <ipython-input-179-10541a58608b>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["minimum_nights"].fillna(0, inplace=True)

# %%
# TODO: replace null values in name and host_name with 'None'
df["host_name"].fillna("None", inplace=True)
# Out:
# <ipython-input-180-9130fa706886>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["host_name"].fillna("None", inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                  0
# name                                1
# host_id                             0
# host_name                           0
# neighbourhood_group                 0
# neighbourhood                       0
# latitude                            5
# longitude                           7
# room_type                           0
# price                               0
# minimum_nights                      0
# number_of_reviews                   0
# last_review                       145
# reviews_per_month                   0
# calculated_host_listings_count      0
# availability_365                    0
# dtype: int64

# %% [markdown]
# #1.2 Delete missing data rows and Drop missing columns

# %%
# TODO: delete last_review mising data row
df.dropna(subset=["last_review"],inplace=True)
df
# Out:
#            id                                              name  host_id  \
# 0        2539                Clean & quiet apt home by the park     2787
# 1        2595                             Skylit Midtown Castle     2845
# 3        3831                   Cozy Entire Floor of Brownstone     4869
# 4        5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5        5099         Large Cozy 1 BR Apartment In Midtown East     7322
# ...       ...                                               ...      ...
# 2991  1742654               High Floor apt.near Columbus Circle  9173924
# 2992  1743116                              Cozy Room in Astoria  8783166
# 2993  1743379    Spacious Historic Williamsburg 2/1.5 Townhouse  9177920
# 2994  1744216  Prime Williamsburg Large bedroom for 1or2 people  2480939
# 2995  1744941                              Charming One Bedroom  6544987
#
#         host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0            John            Brooklyn      Kensington  40.64749  -73.97237
# 1        Jennifer           Manhattan         Midtown  40.75362  -73.98377
# 3     LisaRoxanne            Brooklyn    Clinton Hill  40.68514  -73.95976
# 4           Laura           Manhattan     East Harlem  40.79851  -73.94399
# 5           Chris           Manhattan     Murray Hill  40.74767  -73.97500
# ...           ...                 ...             ...       ...        ...
# 2991          Jon           Manhattan  Hell's Kitchen  40.76708  -73.98600
# 2992      Marinez              Queens         Astoria  40.76549  -73.92934
# 2993         Irie            Brooklyn    Williamsburg  40.70982  -73.96420
# 2994      Charles            Brooklyn    Williamsburg  40.71973  -73.96071
# 2995      Timothy           Manhattan        Kips Bay  40.74148  -73.98304
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 0        Private room  149.0             1.0                  9  2018-10-19
# 1     Entire home/apt  225.0             1.0                 45  2019-05-21
# 3     Entire home/apt   89.0             1.0                270  2019-07-05
# 4     Entire home/apt   80.0            10.0                  9  2018-11-19
# 5     Entire home/apt  200.0             3.0                 74  2019-06-22
# ...               ...    ...             ...                ...         ...
# 2991  Entire home/apt  200.0             2.0                119  2019-07-07
# 2992     Private room  100.0             3.0                  4  2019-06-02
# 2993  Entire home/apt  250.0             3.0                144  2019-07-05
# 2994     Private room   85.0             1.0                221  2019-06-26
# 2995  Entire home/apt  100.0             3.0                  3  2015-09-10
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 0                  0.21                               6               365
# 1                  0.38                               2               355
# 3                  4.64                               1               194
# 4                  0.10                               1                 0
# 5                  0.59                               1               129
# ...                 ...                             ...               ...
# 2991               1.89                               1               216
# 2992               0.07                               2               364
# 2993               2.06                               1               128
# 2994               4.10                               3               206
# 2995               0.05                               1                 0
#
# [2851 rows x 16 columns]

# %%
#axis=1 (columns)
# df.dropna(axis=1, inplace=True)

# %%
# TODO: Drop specific columns (latitude and longitude)
df.drop(["latitude", "longitude"], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# #2. Data in Wrong Format

# %%
df['last_review'] = pd.to_datetime(df['last_review'], format='%Y-%m-%d')

# %%
df['last_review'].head()
len(df['last_review'])
# Out:
# 2851

# %%
# TODO: Remove data rows that are not valid Date format.
df.dropna(subset=["last_review"],inplace=True)
len(df['last_review'])
# Out:
# 2851

# %% [markdown]
# #3. Wrong Data (Outlier)

# %%
# Replace data rows that the column "availability_365" > 365 to 365

for x in df.index:
  if df.loc[x, "availability_365"] > 365:
      df.loc[x, "availability_365"] = 365

# %%
df.loc[8]
# Out:
# id                                                              5203
# name                              Cozy Clean Guest Room - Family Apt
# host_id                                                         7490
# host_name                                                  MaryEllen
# neighbourhood_group                                        Manhattan
# neighbourhood                                        Upper West Side
# room_type                                               Private room
# price                                                         159.28
# minimum_nights                                                   2.0
# number_of_reviews                                                118
# last_review                                      2019-10-11 00:00:00
# reviews_per_month                                               0.99
# calculated_host_listings_count                                     1
# availability_365                                                   0
# Name: 8, dtype: object

# %% [markdown]
# #4. Remove Duplicates

# %%
# Check for duplicated data
print(df.duplicated().any())
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# 2

# %%
# TODO : Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False
